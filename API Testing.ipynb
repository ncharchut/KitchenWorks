# %%
from googlesheetrequest import GSheetsRequest
from files import names, tasks

# %%
editors = ["nicholas.charchut@gmail.com", "sweeney.connorj@gmail.com"]
spreadsheetId = "1vMFRfLKJV2hJv1KW2KgP52Ltv6-g8MzCL0sNyt9pApM"
gsheets = GSheetsRequest(editors, names, tasks, spreadsheetId)

# %%
gsheets.new_week()
# Out:
# All tasks added.
# ({'majorDimension': 'COLUMNS',
#   'range': 'Sheet2!B22:H22',
#   'values': [['Monday (07/23)'],
#    ['Tuesday (07/24)'],
#    ['Wednesday (07/26)'],
#    ['Thursday (07/29)'],
#    ['Friday (08/02)'],
#    ['Saturday (08/07)'],
#    ['Sunday (08/13)']]},
#  {'majorDimension': 'ROWS',
#   'range': 'Sheet2!A23:A30',
#   'values': [['Dinner Setup (3 credits)'],
#    ['Dishes (3 credits)'],
#    ['Dinner Cleanup (3 credits)'],
#    ['Mop Kitchen (3 credits)'],
#    ['Pans 1 (3 credits)'],
#    ['Pans 2 (3 credits)'],
#    ['Leftover Removal (4 credits)']]},
#  [{'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 23,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 22},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 24,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 23},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 25,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 24},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 26,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 25},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 27,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 26},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 28,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 27},
#     'rows': {'values': [{'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}}]}}},
#   {'updateCells': {'fields': 'userEnteredFormat.backgroundColor, dataValidation',
#     'range': {'endColumnIndex': 9,
#      'endRowIndex': 29,
#      'sheetId': 1151614688,
#      'startColumnIndex': 1,
#      'startRowIndex': 28},
#     'rows': {'values': [{'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}},
#       {'dataValidation': {'condition': {'type': 'ONE_OF_LIST',
#          'values': [{'userEnteredValue': 'Nicholas Charchut'},
#           {'userEnteredValue': 'Connor Sweeney'},
#           {'userEnteredValue': 'PJ Callahan'},
#           {'userEnteredValue': 'Thomas Dudzik'},
#           {'userEnteredValue': 'Jacob Phillips'},
#           {'userEnteredValue': 'Jack Strachan'}]},
#         'inputMessage': 'Type your full name or select it from the dropdown menu.',
#         'showCustomUi': True,
#         'strict': True}},
#       {'userEnteredFormat': {'backgroundColor': {'blue': 0,
#          'green': 0,
#          'red': 0}}}]}}}])

# %%
gsheets.full_send()
